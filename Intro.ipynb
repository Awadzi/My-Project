# %% [markdown]
# <a href="https://colab.research.google.com/github/Awadzi/My-Project/blob/master/Intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(3): print ("Hello AI Scholars")
# Out:
# Hello AI Scholars
# Hello AI Scholars
# Hello AI Scholars

# %%
sensor_id = "SN-4092"
temperature = 31.5
pump_active = True
fish_count = 1500

print(f"Sensor {sensor_id} reports a temp of {temperature} & the pond has {fish_count} fish.")
# Out:
# Sensor SN-4092 reports a temp of 31.5 & the pond has 1500 fish.

# %%
sensor_id = "ESP32"
temperature = 31.5
pump_active = True
fish_count = input("How many fish are in the pond:")

print(f"Sensor {sensor_id} reports a temp of {temperature} & the pond has {fish_count} fish.")

if pump_active ==True:
  print(f"Water would be changed in 20 minutes times")
# Out:
# How many fish are in the pond:5000
# Sensor ESP32 reports a temp of 31.5 & the pond has 5000 fish.
# Water would be changed in 20 minutes times
